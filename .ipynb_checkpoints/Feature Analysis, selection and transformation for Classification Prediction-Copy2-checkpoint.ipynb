# %%
import pandas as pd
import numpy as np
import json
from IPython.display import display
import pickle
from tqdm import tqdm
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.metrics import  accuracy_score,classification_report,roc_auc_score,log_loss,zero_one_loss,confusion_matrix
def feature_plot(imp_features,X):
    indices = np.argsort(imp_features)[::-1]
    num_features=len(imp_features[imp_features>0])
    columns = X.columns.values[indices][:num_features]
    values=imp_features[indices][:num_features]

    plt.figure(figsize = (15,5))
    plt.title("Feature importances")
    plt.barh(range(num_features), values, align="center")
    plt.yticks(range(num_features), columns)
    plt.ylim([ num_features,-1])
    plt.show() 

def classification_metric(y_true,y_predict):
    print('accuracy score',accuracy_score(y_true,y_predict))
    print('roc_auc_score',roc_auc_score(y_true, y_predict))
    print('log loss score',log_loss(y_true,y_predict))
    print('zero_one_loss score',zero_one_loss(y_true,y_predict))
    print('confusion_matrix',confusion_matrix(y_true,y_predict))
    print(classification_report(y_true,y_predict))

# %%
processed_data=pickle.load(open('processed_data.p', "rb" ))
processed_data=processed_data.sort_values(['date','player_name'])

# %% [markdown]
# ## remove additional fields:

# %% [markdown]
# ### Generate data options
# option 1: generate data by using the op and cp range
#          - combine data of the op range and determine if there is a cp output
# option 2: have a range for every record
#          - example: 1. looks at record+1 and if record within time range is true then identiyf whether it is a churned user.

# %% [markdown]
# #fields to consider:
#         #Hasgroup
#         #server
#             #bad server = churned user?
#             #appears like a long shot tho , the correlation!=causality idea

# %%
data.dtypes
# Out:
# mean_score           float64
# games_played           int64
# total_time_played    float64
# win_ratio            float64
# max_player_points      int64
# max_dist_visit       float64
# std_dist_visit       float64
# max_duration         float64
# player                object
# churned                int64
# dtype: object

# %%
processed_data.isnull().sum()
# Out:
# index            0
# date             0
# duration         0
# finished         0
# group            0
# server           0
# timeLimit        0
# player_degree    0
# player_name      0
# player_points    0
# player_score     0
# team_score       0
# win              0
# dtype: int64

# %%
processed_data
# Out:
#         index                date  duration  finished group  \
# 2           0 2015-05-25 17:49:57     22562         1
# 6           0 2015-05-25 17:49:57     22562         1
# 1           0 2015-05-25 17:49:57     22562         1
# 5           0 2015-05-25 17:49:57     22562         1
# 7           0 2015-05-25 17:49:57     22562         1
# 0           0 2015-05-25 17:49:57     22562         1
# 3           0 2015-05-25 17:49:57     22562         1
# 4           0 2015-05-25 17:49:57     22562         1
# 93865   11086 2015-05-25 18:00:17      8269         1
# 93860   11086 2015-05-25 18:00:17      8269         1
# 93864   11086 2015-05-25 18:00:17      8269         1
# 93863   11086 2015-05-25 18:00:17      8269         1
# 93859   11086 2015-05-25 18:00:17      8269         1
# 93858   11086 2015-05-25 18:00:17      8269         1
# 93861   11086 2015-05-25 18:00:17      8269         1
# 93862   11086 2015-05-25 18:00:17      8269         1
# 164155  19379 2015-05-25 18:15:29     38877         1
# 164160  19379 2015-05-25 18:15:29     38877         1
# 164158  19379 2015-05-25 18:15:29     38877         1
# 164159  19379 2015-05-25 18:15:29     38877         1
# 164154  19379 2015-05-25 18:15:29     38877         1
# 164151  19379 2015-05-25 18:15:29     38877         1
# 164152  19379 2015-05-25 18:15:29     38877         1
# 164153  19379 2015-05-25 18:15:29     38877         1
# 164161  19379 2015-05-25 18:15:29     38877         1
# 164157  19379 2015-05-25 18:15:29     38877         1
# 164156  19379 2015-05-25 18:15:29     38877         1
# 173480  20478 2015-05-25 18:48:43      8969         1
# 173479  20478 2015-05-25 18:48:43      8969         1
# 173481  20478 2015-05-25 18:48:43      8969         1
# ...       ...                 ...       ...       ...   ...
# 161581  19067 2015-06-20 05:36:56     18055         1
# 161575  19067 2015-06-20 05:36:56     18055         1
# 161579  19067 2015-06-20 05:36:56     18055         1
# 161609  19071 2015-06-20 05:37:59     32310         1
# 161613  19071 2015-06-20 05:37:59     32310         1
# 161617  19071 2015-06-20 05:37:59     32310         1
# 161615  19071 2015-06-20 05:37:59     32310         1
# 161611  19071 2015-06-20 05:37:59     32310         1
# 161614  19071 2015-06-20 05:37:59     32310         1
# 161612  19071 2015-06-20 05:37:59     32310         1
# 161616  19071 2015-06-20 05:37:59     32310         1
# 161610  19071 2015-06-20 05:37:59     32310         1
# 161603  19070 2015-06-20 05:38:31     26516         1
# 161601  19070 2015-06-20 05:38:31     26516         1
# 161606  19070 2015-06-20 05:38:31     26516         1
# 161602  19070 2015-06-20 05:38:31     26516         1
# 161599  19070 2015-06-20 05:38:31     26516         1
# 161604  19070 2015-06-20 05:38:31     26516         1
# 161600  19070 2015-06-20 05:38:31     26516         1
# 161607  19070 2015-06-20 05:38:31     26516         1
# 161608  19070 2015-06-20 05:38:31     26516         1
# 161605  19070 2015-06-20 05:38:31     26516         1
# 161594  19069 2015-06-20 05:42:38      7395         1
# 161593  19069 2015-06-20 05:42:38      7395         1
# 161592  19069 2015-06-20 05:42:38      7395         1
# 161596  19069 2015-06-20 05:42:38      7395         1
# 161591  19069 2015-06-20 05:42:38      7395         1
# 161595  19069 2015-06-20 05:42:38      7395         1
# 161597  19069 2015-06-20 05:42:38      7395         1
# 161598  19069 2015-06-20 05:42:38      7395         1
#
#                                 server  timeLimit  player_degree  \
# 2          tagpro-chord.koalabeast.com         12             31
# 6          tagpro-chord.koalabeast.com         12             89
# 1          tagpro-chord.koalabeast.com         12              0
# 5          tagpro-chord.koalabeast.com         12             57
# 7          tagpro-chord.koalabeast.com         12             54
# 0          tagpro-chord.koalabeast.com         12             99
# 3          tagpro-chord.koalabeast.com         12             95
# 4          tagpro-chord.koalabeast.com         12             43
# 93865      tagpro-chord.koalabeast.com         12              0
# 93860      tagpro-chord.koalabeast.com         12              0
# 93864      tagpro-chord.koalabeast.com         12              0
# 93863      tagpro-chord.koalabeast.com         12             83
# 93859      tagpro-chord.koalabeast.com         12              8
# 93858      tagpro-chord.koalabeast.com         12             77
# 93861      tagpro-chord.koalabeast.com         12             95
# 93862      tagpro-chord.koalabeast.com         12             91
# 164155     tagpro-chord.koalabeast.com         12             85
# 164160     tagpro-chord.koalabeast.com         12             68
# 164158     tagpro-chord.koalabeast.com         12             26
# 164159     tagpro-chord.koalabeast.com         12             75
# 164154     tagpro-chord.koalabeast.com         12             16
# 164151     tagpro-chord.koalabeast.com         12             55
# 164152     tagpro-chord.koalabeast.com         12              0
# 164153     tagpro-chord.koalabeast.com         12             95
# 164161     tagpro-chord.koalabeast.com         12              0
# 164157     tagpro-chord.koalabeast.com         12              0
# 164156     tagpro-chord.koalabeast.com         12              0
# 173480     tagpro-chord.koalabeast.com         12             74
# 173479     tagpro-chord.koalabeast.com         12             76
# 173481     tagpro-chord.koalabeast.com         12             10
# ...                                ...        ...            ...
# 161581  tagpro-diameter.koalabeast.com         12             75
# 161575  tagpro-diameter.koalabeast.com         12              0
# 161579  tagpro-diameter.koalabeast.com         12             74
# 161609    tagpro-radius.koalabeast.com         12            153
# 161613    tagpro-radius.koalabeast.com         12             45
# 161617    tagpro-radius.koalabeast.com         12             55
# 161615    tagpro-radius.koalabeast.com         12             97
# 161611    tagpro-radius.koalabeast.com         12             60
# 161614    tagpro-radius.koalabeast.com         12             65
# 161612    tagpro-radius.koalabeast.com         12            113
# 161616    tagpro-radius.koalabeast.com         12             51
# 161610    tagpro-radius.koalabeast.com         12              0
# 161603    tagpro-centra.koalabeast.com         12             77
# 161601    tagpro-centra.koalabeast.com         12             78
# 161606    tagpro-centra.koalabeast.com         12             96
# 161602    tagpro-centra.koalabeast.com         12             98
# 161599    tagpro-centra.koalabeast.com         12             48
# 161604    tagpro-centra.koalabeast.com         12              0
# 161600    tagpro-centra.koalabeast.com         12              0
# 161607    tagpro-centra.koalabeast.com         12             85
# 161608    tagpro-centra.koalabeast.com         12            162
# 161605    tagpro-centra.koalabeast.com         12             78
# 161594    tagpro-sphere.koalabeast.com         12             40
# 161593    tagpro-sphere.koalabeast.com         12             68
# 161592    tagpro-sphere.koalabeast.com         12             28
# 161596    tagpro-sphere.koalabeast.com         12             99
# 161591    tagpro-sphere.koalabeast.com         12            109
# 161595    tagpro-sphere.koalabeast.com         12              3
# 161597    tagpro-sphere.koalabeast.com         12            110
# 161598    tagpro-sphere.koalabeast.com         12              0
#
#          player_name  player_points  player_score  team_score  win
# 2               2Pop             29            19         3.0  1.0
# 6            Android             31            50         3.0  1.0
# 1       BartimaeusJr              0            56         3.0  1.0
# 5               Koba             25            37         1.0  0.0
# 7        Real Torres             26            46         1.0  0.0
# 0           RoDyMaRy             25            31         1.0  0.0
# 3            Ronding             25            30         1.0  0.0
# 4              hello             29            30         3.0  1.0
# 93865   BartimaeusJr              0            31         0.0  0.0
# 93860   BlankBanshee              0            49         1.0  0.0
# 93864       Euclides              0            28         0.0  0.0
# 93863    HungryHippo              6            34         0.0  0.0
# 93859       MrWaReZz              8            33         1.0  0.0
# 93858         Raylan             10            69         3.0  1.0
# 93861        Ronding              9            24         3.0  1.0
# 93862    lickmybrain              8            33         0.0  0.0
# 164155           171             35            21         0.0  0.0
# 164160        H-Ball             28            30         0.0  0.0
# 164158      LukaBear             34            27         0.0  0.0
# 164159   Marco Ballo             43            33         0.0  0.0
# 164154         Muccy              0             0         3.0  1.0
# 164151  Potence Ball             48            57         3.0  1.0
# 164152         Radon              0             0         2.0  0.0
# 164153       Ronding             38            55         2.0  0.0
# 164161  Some Ball 11              0            34         0.0  0.0
# 164157   Some Ball 7              0            24         0.0  0.0
# 164156             X              0             0         0.0  0.0
# 173480       .Vector              6            32         0.0  0.0
# 173479        Camfah             17            81         3.0  1.0
# 173481         Felix              6            25         0.0  0.0
# ...              ...            ...           ...         ...  ...
# 161581     Ultimatum             14            26         0.0  0.0
# 161575     grief egg              0            22         0.0  0.0
# 161579  xxbongsmoker             10            27         0.0  0.0
# 161609     BilldaCat             51            65         3.0  1.0
# 161613    Crow's Eye             49            44         3.0  1.0
# 161617       Kerball             26            23         0.0  0.0
# 161615  Lapis Lazuli             49            43         3.0  1.0
# 161611         Riolu             28            24         1.0  0.0
# 161614         Satan             29            31         1.0  0.0
# 161612   TagUpTurnUp             48            31         3.0  1.0
# 161616   rishabhhhhh              0             0         1.0  0.0
# 161610       tnevlos              0            39         1.0  0.0
# 161603        Danger              0             0         3.0  1.0
# 161601     FunkyMnky             33            32         3.0  1.0
# 161606  Greenbastard             30            18         0.0  0.0
# 161602   Nick Lachey              0             0         2.0  0.0
# 161599     PopOMatic             29            22         2.0  0.0
# 161604   Some Ball 2              0            38         2.0  0.0
# 161600         [box]              0            45         3.0  1.0
# 161607       sadball             27            34         0.0  0.0
# 161608       senpai.             19            31         0.0  0.0
# 161605   spothazards             33            57         0.0  0.0
# 161594   C. Roballdo              6            25         0.0  0.0
# 161593       Cyanide             12            62         3.0  1.0
# 161592       FitChip              6            22         0.0  0.0
# 161596   HoneyBadger             12            62         3.0  1.0
# 161591  Juicepockets             11            19         3.0  1.0
# 161595  Mongoliabeef              6            32         0.0  0.0
# 161597   Sansa Stark             12            50         3.0  1.0
# 161598        jsh348              0            28         0.0  0.0
#
# [229742 rows x 13 columns]

# %%
def get_field_summary(data):
    new_data=[]
    
    #min_score
    new_data.append(data['player_score'].min())
    #mean_score
    new_data.append(data['player_score'].mean())
    #max_score
    new_data.append(data['player_score'].max())
    
    #sd_score
    new_data.append(data['player_score'].std())
    
    
    #total_games_played
    games_played=data.shape[0]

    #score_ratio
    new_data.append(data['player_score'].sum()/games_played)
    
    new_data.append(games_played)
    #games won
    new_data.append(data['win'].sum())
    #win_ratio
    new_data.append(data['win'].sum()/games_played)
    #SECONDS,total_hours_played
    new_data.append(data['duration'].sum()/60)
    #avg_game_duration(seconds)
    new_data.append(data['duration'].mean()/60)
    #avg_player_degree(~~)
    new_data.append(data['player_degree'].mean())
    #avg_player_points(rank)
    new_data.append(data['player_points'].mean())
    #max_player_points(rank)
    new_data.append(data['player_points'].max())
    #avg_team_score
    new_data.append(data['team_score'].mean())
    #max_team_score
    new_data.append(data['team_score'].max())
    #team score ratio
    new_data.append(data['team_score'].sum()/games_played)
    #avg_time_limit
    new_data.append(data['timeLimit'].mean())
    
    #max_duration
    new_data.append(data['duration'].max()/60)
    #min_duration
    new_data.append(data['duration'].min()/60)
    #max_player_degree
    new_data.append(data['player_degree'].max())
    #min_player_degree
    new_data.append(data['player_degree'].min())
   
    #avg_dist_visit
    distance_data=data['date'].diff().dt.total_seconds()
    #avg_dist_visit=data['date'].diff().dt.total_seconds().mean()
    avg_dist_visit=distance_data.mean()
    avg_dist_visit/=60
    new_data.append(0 if np.isnan(avg_dist_visit) else avg_dist_visit)

    #max_dist_visit
    max_dist_visit=distance_data.max()
    max_dist_visit/=60
    new_data.append(0 if np.isnan(max_dist_visit) else max_dist_visit)
    
    #min_dist_visit
    min_dist_visit=distance_data.min()
    min_dist_visit/=60
    new_data.append(0 if np.isnan(min_dist_visit) else min_dist_visit)    
    
    #std_dist_visit
    std_dist_visit=distance_data.std()
    std_dist_visit/=60
    new_data.append(0 if np.isnan(std_dist_visit) else std_dist_visit)
    #has_group
    has_group=(data['group'].isin(['redacted']).sum())!=0
    new_data.append(1 if has_group else 0)
    
    return new_data
    
def generate_data(data,op=5,cp=5):
    col_names =  ['min_score', 'mean_score', 'max_score','std_score','player_score_ratio','games_played','games_won','win_ratio',
                  'hours_played','avg_game_duration'
                  ,'avg_player_degree','avg_player_points','max_player_points','avg_team_score','max_team_score',
                  'team_score_ratio','avg_time_limit',
                  'max_duration','min_duration','max_player_degree','min_player_degree','avg_dist_visit','max_dist_visit',
                  'min_dist_visit','std_dist_visit','has_group',
                  
                  
                  'player','churned']
    
    new_data=[]
    for x in tqdm(data['player_name'].unique()):
    #for x in set(processed_data[:50].player_name):
        player_data=data.loc[data['player_name']==x]
        
        op_min_date=player_data['date'].min()
        op_max_date=op_min_date+ pd.DateOffset(days=op)
        cp_max_date=op_max_date+ pd.DateOffset(days=cp)
        
        op_data=player_data.loc[(player_data['date'] >= op_min_date) & (player_data['date'] <= op_max_date)]
        
        
        cp_data=player_data.loc[(player_data['date'] > op_max_date) & (player_data['date'] <= cp_max_date)]
        summary=get_field_summary(op_data)
        
        summary.append(x)
        summary.append(1 if cp_data.empty else 0 )
        
        new_data.append(summary)
        #display(player_data)
    return pd.DataFrame(new_data,columns=col_names)
    
data=generate_data(processed_data.copy())
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 14629/14629 [05:55<00:00, 41.18it/s]

# %%
#pickle.dump(data,open('checkpoint_processed_data.p', "wb" ))

# %%
#data=pickle.load(open('checkpoint_processed_data.p','rb'))

# %%
columns=['mean_score','games_played','hours_played','win_ratio',
                 'max_player_points','max_dist_visit','std_dist_visit','max_duration'
                  ,'player','churned']

data=data[columns]

# %%
from sklearn.preprocessing import MinMaxScaler,StandardScaler,Normalizer
def scale_numerical_data(data,scale=False):
    if scale: 
        scaler=StandardScaler()
        columns_to_encode=list(data.select_dtypes(include=['float64','int64']))
        columns_to_encode.remove('churned')


       # skewed=['avg_game_duration','avg_dist_visit','avg_player_degree','avg_team_score','has_group',
       #         'max_duration','max_dist_visit']
       # features_log_transformed = pd.DataFrame(data = data)
       # features_log_transformed[skewed] = data[skewed].apply(lambda x: np.log(x + 1))

        features_transform = pd.DataFrame(data = data)
        features_transform[columns_to_encode] = scaler.fit_transform(data[columns_to_encode])
        return features_transform
    else:
        return data
data=scale_numerical_data(data,False)

# %%
#data.head(6)
data=data.fillna(0)
X=data.drop(['churned','player'],axis=1)
y=data['churned']

# %%
data.hist(figsize=(15,10));

# %%
import matplotlib.pyplot as plt
corr = data.corr()
churn_corr=corr.sort_values('churned',ascending=True)
churn_corr=churn_corr['churned']
churn_corr.plot('barh')
plt.show();

churn_corr=corr.sort_values('churned',ascending=False)
print(churn_corr['churned'])
# Out:
# churned              1.000000
# win_ratio           -0.028678
# mean_score          -0.050894
# max_duration        -0.233235
# max_player_points   -0.257405
# games_played        -0.310968
# hours_played        -0.311554
# std_dist_visit      -0.387577
# max_dist_visit      -0.479041
# Name: churned, dtype: float64

# %%
from sklearn.cross_validation import train_test_split
random_state=42
#X=X.drop(['games_won'],axis=1)
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=random_state)

print('x_train',X_train.shape[0])
print('x_test',X_test.shape[0])
# Out:
# x_train 11703
# x_test 2926

# %%
from sklearn.linear_model import LogisticRegression
clf=LogisticRegression()
clf.fit(X,y)
pred=clf.predict(X)
classification_metric(y,pred)
# Out:
# accuracy score 0.7790689725886937
# roc_auc_score 0.7245201345548823
# log loss score 7.630803011587506
# zero_one_loss score 0.22093102741130632
# confusion_matrix [[2727 2116]
#  [1116 8670]]
#              precision    recall  f1-score   support
#
#           0       0.71      0.56      0.63      4843
#           1       0.80      0.89      0.84      9786
#
# avg / total       0.77      0.78      0.77     14629

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier,GradientBoostingClassifier,AdaBoostClassifier
from sklearn.linear_model import SGDClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
#clf_A = DecisionTreeClassifier(random_state=random_state)
clf_B = RandomForestClassifier(random_state=random_state)
clf_C = GradientBoostingClassifier(random_state=random_state)
clf_D = AdaBoostClassifier(random_state=random_state)

#clf_E = SVC(random_state=random_state)
for clf in [
    clf_B,clf_C,clf_D]:
    print('classifier: ',clf.__class__.__name__)
    clf.fit(X_train,y_train)
    #imp_features=clf.feature_importances_
    #feature_plot(imp_features,X)
    pred=clf.predict(X_test)
    classification_metric(y_test,pred)
# Out:
# classifier:  RandomForestClassifier
# accuracy score 0.7419685577580314
# roc_auc_score 0.7066730913778696
# log loss score 8.912197136279143
# zero_one_loss score 0.2580314422419686
# confusion_matrix [[ 587  391]
#  [ 364 1584]]
#              precision    recall  f1-score   support
#
#           0       0.62      0.60      0.61       978
#           1       0.80      0.81      0.81      1948
#
# avg / total       0.74      0.74      0.74      2926
#
# classifier:  GradientBoostingClassifier
# accuracy score 0.7843472317156528
# roc_auc_score 0.7410463461029718
# log loss score 7.448486859811875
# zero_one_loss score 0.2156527682843472
# confusion_matrix [[ 597  381]
#  [ 250 1698]]
#              precision    recall  f1-score   support
#
#           0       0.70      0.61      0.65       978
#           1       0.82      0.87      0.84      1948
#
# avg / total       0.78      0.78      0.78      2926
#
# classifier:  AdaBoostClassifier
# accuracy score 0.780246069719754
# roc_auc_score 0.7458580558739917
# log loss score 7.590127505477833
# zero_one_loss score 0.21975393028024603
# confusion_matrix [[ 628  350]
#  [ 293 1655]]
#              precision    recall  f1-score   support
#
#           0       0.68      0.64      0.66       978
#           1       0.83      0.85      0.84      1948
#
# avg / total       0.78      0.78      0.78      2926

# %%
import statsmodels.api as sm
#X2 = sm.add_constant(X)
est = sm.OLS(y, X)
est2 = est.fit()
print(est2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                churned   R-squared:                       0.642
# Model:                            OLS   Adj. R-squared:                  0.641
# Method:                 Least Squares   F-statistic:                     1744.
# Date:                Sat, 30 Jun 2018   Prob (F-statistic):               0.00
# Time:                        02:37:15   Log-Likelihood:                -9913.7
# No. Observations:               14629   AIC:                         1.986e+04
# Df Residuals:                   14614   BIC:                         1.997e+04
# Df Model:                          15
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# mean_score            0.0109      0.001     19.473      0.000       0.010       0.012
# max_score            -0.0047      0.001     -9.210      0.000      -0.006      -0.004
# std_score             0.0082      0.001     11.466      0.000       0.007       0.010
# games_played          0.0746      0.002     31.575      0.000       0.070       0.079
# games_won            -0.0121      0.003     -4.331      0.000      -0.018      -0.007
# hours_played         -0.0002   6.39e-06    -33.988      0.000      -0.000      -0.000
# avg_game_duration     0.0018    6.1e-05     30.134      0.000       0.002       0.002
# avg_player_degree     0.0003      0.000      0.794      0.427      -0.000       0.001
# avg_player_points    -0.0003      0.001     -0.359      0.719      -0.002       0.001
# max_player_points    -0.0023      0.001     -4.031      0.000      -0.003      -0.001
# min_duration         -0.0002   6.12e-05     -2.930      0.003      -0.000   -5.94e-05
# max_player_degree    -0.0001      0.000     -0.359      0.719      -0.001       0.001
# avg_dist_visit      4.78e-05   8.06e-06      5.929      0.000     3.2e-05    6.36e-05
# max_dist_visit       -0.0001   7.21e-06    -19.006      0.000      -0.000      -0.000
# std_dist_visit     3.794e-05   1.04e-05      3.660      0.000    1.76e-05    5.83e-05
# ==============================================================================
# Omnibus:                      927.140   Durbin-Watson:                   1.546
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1384.577
# Skew:                          -0.537   Prob(JB):                    2.20e-301
# Kurtosis:                       4.058   Cond. No.                     2.78e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.78e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
from sklearn.ensemble import AdaBoostClassifier,GradientBoostingClassifier,RandomForestClassifier

clf=AdaBoostClassifier()
clf.fit(X,y)
imp_features=clf.feature_importances_
feature_plot(imp_features,X)
pred=clf.predict(X)
classification_metric(y,pred)
# Out:
# accuracy score 0.784400847631417
# roc_auc_score 0.7607813639752472
# log loss score 7.446626894704744
# zero_one_loss score 0.21559915236858296
# confusion_matrix [[3604 1756]
#  [1398 7871]]
#              precision    recall  f1-score   support
#
#           0       0.72      0.67      0.70      5360
#           1       0.82      0.85      0.83      9269
#
# avg / total       0.78      0.78      0.78     14629

# %%
clf=GradientBoostingClassifier()
clf.fit(X,y)
imp_features=clf.feature_importances_
feature_plot(imp_features,X)
pred=clf.predict(X)
classification_metric(y,pred)
# Out:
# accuracy score 0.7936974502700116
# roc_auc_score 0.7656392053917488
# log loss score 7.125537058415884
# zero_one_loss score 0.2063025497299884
# confusion_matrix [[3541 1819]
#  [1199 8070]]
#              precision    recall  f1-score   support
#
#           0       0.75      0.66      0.70      5360
#           1       0.82      0.87      0.84      9269
#
# avg / total       0.79      0.79      0.79     14629

# %%
clf=RandomForestClassifier()
clf.fit(X,y)
imp_features=clf.feature_importances_
feature_plot(imp_features,X)
pred=clf.predict(X)
classification_metric(y,pred)
# Out:
# accuracy score 0.9855765944357099
# roc_auc_score 0.9852740458082873
# log loss score 0.49817142560036465
# zero_one_loss score 0.014423405564290115
# confusion_matrix [[5275   85]
#  [ 126 9143]]
#              precision    recall  f1-score   support
#
#           0       0.98      0.98      0.98      5360
#           1       0.99      0.99      0.99      9269
#
# avg / total       0.99      0.99      0.99     14629

# %%
from sklearn.linear_model import LogisticRegression
clf=LogisticRegression()
clf.fit(X_train,y_train)
pred=clf.predict(X_test)
classification_metric(y_test,pred)
# Out:
# accuracy score 0.7686261107313739
# roc_auc_score 0.731997782996164
# log loss score 7.991489898918887
# zero_one_loss score 0.23137388926862612
# confusion_matrix [[ 638  435]
#  [ 242 1611]]
#              precision    recall  f1-score   support
#
#           0       0.72      0.59      0.65      1073
#           1       0.79      0.87      0.83      1853
#
# avg / total       0.76      0.77      0.76      2926

# %%
from sklearn.model_selection import KFold
clf=GradientBoostingClassifier(random_state=random_state)
cv=KFold(n_splits=10, random_state=random_state, shuffle=True)
dis_list=[]
for train, test in cv.split(X_train, y_train):
        dis_list=test
        clf.fit(X_train.iloc[train], y_train.iloc[train])
        
        pred=clf.predict(X_train.iloc[test])
        classification_metric(y_train.iloc[test],pred)
    
    
pred=clf.predict(X_test)
#classification_metric(y_test,pred)
print(pred)
classification_metric(y_test,pred)
# Out:
# accuracy score 0.7882152006831767
# roc_auc_score 0.7596795538330655
# log loss score 7.314888203894183
# zero_one_loss score 0.21178479931682326
# confusion_matrix [[279 147]
#  [101 644]]
#              precision    recall  f1-score   support
#
#           0       0.73      0.65      0.69       426
#           1       0.81      0.86      0.84       745
#
# avg / total       0.79      0.79      0.79      1171
#
# accuracy score 0.7822374039282665
# roc_auc_score 0.749979326883321
# log loss score 7.5213567206782095
# zero_one_loss score 0.21776259607173354
# confusion_matrix [[266 151]
#  [104 650]]
#              precision    recall  f1-score   support
#
#           0       0.72      0.64      0.68       417
#           1       0.81      0.86      0.84       754
#
# avg / total       0.78      0.78      0.78      1171
#
# accuracy score 0.8018787361229718
# roc_auc_score 0.781728874106923
# log loss score 6.842960263078262
# zero_one_loss score 0.19812126387702822
# confusion_matrix [[313 138]
#  [ 94 626]]
#              precision    recall  f1-score   support
#
#           0       0.77      0.69      0.73       451
#           1       0.82      0.87      0.84       720
#
# avg / total       0.80      0.80      0.80      1171
#
# accuracy score 0.7871794871794872
# roc_auc_score 0.7517619047619047
# log loss score 7.350667400965215
# zero_one_loss score 0.21282051282051284
# confusion_matrix [[263 157]
#  [ 92 658]]
#              precision    recall  f1-score   support
#
#           0       0.74      0.63      0.68       420
#           1       0.81      0.88      0.84       750
#
# avg / total       0.78      0.79      0.78      1170
#
# accuracy score 0.7931623931623931
# roc_auc_score 0.7660409765672924
# log loss score 7.14401626461396
# zero_one_loss score 0.20683760683760688
# confusion_matrix [[285 144]
#  [ 98 643]]
#              precision    recall  f1-score   support
#
#           0       0.74      0.66      0.70       429
#           1       0.82      0.87      0.84       741
#
# avg / total       0.79      0.79      0.79      1170
#
# accuracy score 0.7846153846153846
# roc_auc_score 0.7546753246753246
# log loss score 7.439214014331622
# zero_one_loss score 0.2153846153846154
# confusion_matrix [[264 136]
#  [116 654]]
#              precision    recall  f1-score   support
#
#           0       0.69      0.66      0.68       400
#           1       0.83      0.85      0.84       770
#
# avg / total       0.78      0.78      0.78      1170
#
# accuracy score 0.8017094017094017
# roc_auc_score 0.7729028068718566
# log loss score 6.848816464646477
# zero_one_loss score 0.19829059829059825
# confusion_matrix [[288 149]
#  [ 83 650]]
#              precision    recall  f1-score   support
#
#           0       0.78      0.66      0.71       437
#           1       0.81      0.89      0.85       733
#
# avg / total       0.80      0.80      0.80      1170
#
# accuracy score 0.7777777777777778
# roc_auc_score 0.7495590828924161
# log loss score 7.675393673387212
# zero_one_loss score 0.2222222222222222
# confusion_matrix [[280 161]
#  [ 99 630]]
#              precision    recall  f1-score   support
#
#           0       0.74      0.63      0.68       441
#           1       0.80      0.86      0.83       729
#
# avg / total       0.77      0.78      0.77      1170
#
# accuracy score 0.7811965811965812
# roc_auc_score 0.7490136071627295
# log loss score 7.557308969483972
# zero_one_loss score 0.2188034188034188
# confusion_matrix [[268 156]
#  [100 646]]
#              precision    recall  f1-score   support
#
#           0       0.73      0.63      0.68       424
#           1       0.81      0.87      0.83       746
#
# avg / total       0.78      0.78      0.78      1170
#
# accuracy score 0.7957264957264957
# roc_auc_score 0.7691903684550743
# log loss score 7.055459399998447
# zero_one_loss score 0.20427350427350432
# confusion_matrix [[292 150]
#  [ 89 639]]
#              precision    recall  f1-score   support
#
#           0       0.77      0.66      0.71       442
#           1       0.81      0.88      0.84       728
#
# avg / total       0.79      0.80      0.79      1170
#
# [0 1 1 ... 0 1 0]
# accuracy score 0.7829801777170198
# roc_auc_score 0.7523536805130493
# log loss score 7.495705418376155
# zero_one_loss score 0.21701982228298022
# confusion_matrix [[ 684  389]
#  [ 246 1607]]
#              precision    recall  f1-score   support
#
#           0       0.74      0.64      0.68      1073
#           1       0.81      0.87      0.84      1853
#
# avg / total       0.78      0.78      0.78      2926
